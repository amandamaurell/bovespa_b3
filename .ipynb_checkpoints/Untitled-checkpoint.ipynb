# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bsp
import re

# %% [markdown]
# # Getting the companies codes from b3.com.br

# %%
url_b3 = 'http://www.b3.com.br/pt_br/produtos-e-servicos/negociacao/renda-variavel/empresas-listadas.htm'

# %%
response = requests.get(url_b3)
soup = bsp(response.content, "html.parser")
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="pt-BR"><head><meta content="emuI4V4FxM9i41NyW8Rpu54C6uik7DcnezlH6O2WXPs" name="google-site-verification"/><script data-dtconfig="rid=RID_-735038931|rpid=-745406660|domain=b3.com.br|reportUrl=/rb_8370fec7-c82e-413f-a2c6-777046ed9811|app=4d5d869272338700|featureHash=ICA27SVfjqrux|srsr=2000|vcv=2|rdnt=1|uxrgce=1|bp=3|cuc=qf4s7dpn|dpvc=1|lastModification=1606999349554|dtVersion=10203201116182134|tp=500,50,0,1|uxdcw=1500|vs=2|agentUri=/ruxitagentjs_ICA27SVfjqrux_10203201116182134.js" src="/ruxitagentjs_ICA27SVfjqrux_10203201116182134.js" type="text/javascript"></script><link href="../../../../lumis-theme/br/com/bvmf/internet/theme/bvmf-internet/css/search.css" rel="stylesheet" type="text/css"/><!--[if lt IE 9]><script type="text/javascript" src="lumis/tool/html5shiv/html5shiv.js"></script><![endif]--><script type="text/javascript">//<![CDATA[
# ...

# %%
companies = []
content = soup.find_all("div", class_='scrollable')
content
# Out:
# []

# %% [markdown]
# ## Saved the code into a txt file to easily access it

# %%
pattern = re.compile(r'codigoCvm=\d+')
numbers = {}
with open('bovespa.txt', 'r', encoding='utf-8', errors='ignore') as file:
    f = file.read()
    numbers['code'] = re.findall(pattern, f)
    print(numbers)
    df= pd.DataFrame(numbers)
# Out:
# {'code': ['codigoCvm=25291', 'codigoCvm=25291', 'codigoCvm=16284', 'codigoCvm=16284', 'codigoCvm=21725', 'codigoCvm=21725', 'codigoCvm=25283', 'codigoCvm=25283', 'codigoCvm=18970', 'codigoCvm=18970', 'codigoCvm=22179', 'codigoCvm=22179', 'codigoCvm=16705', 'codigoCvm=16705', 'codigoCvm=9954', 'codigoCvm=9954', 'codigoCvm=21032', 'codigoCvm=21032', 'codigoCvm=22357', 'codigoCvm=22357', 'codigoCvm=24953', 'codigoCvm=24953', 'codigoCvm=10456', 'codigoCvm=10456', 'codigoCvm=22217', 'codigoCvm=22217', 'codigoCvm=18066', 'codigoCvm=18066', 'codigoCvm=21490', 'codigoCvm=21490', 'codigoCvm=23264', 'codigoCvm=23264', 'codigoCvm=24961', 'codigoCvm=24961', 'codigoCvm=3050', 'codigoCvm=3050', 'codigoCvm=23248', 'codigoCvm=23248', 'codigoCvm=22349', 'codigoCvm=22349', 'codigoCvm=24171', 'codigoCvm=24171', 'codigoCvm=19100', 'codigoCvm=19100', 'codigoCvm=15423', 'codigoCvm=15423', 'codigoCvm=80187', 'codigoCvm=80187', 'codigoCvm=11975', 'codigoCvm=11975', 'codigoCvm=24112', 'codigoCvm=24112', 'cod
# ...

# %% [markdown]
# ## Turning into a df to drop duplicates and get the clean code number

# %%
df = df.drop_duplicates()

# %%
df['code'] = df['code'].map(lambda x: x.strip('codigoCvm='))

# %% [markdown]
# ### Testing if it works with different codes

# %%
code = '25291'
url_bovespa = f'http://bvmf.bmfbovespa.com.br/cias-listadas/empresas-listadas/ResumoEmpresaPrincipal.aspx?codigoCvm={code}&idioma=pt-br'

# %% [markdown]
# ## Using the general url to get the url contained in the iframe

# %%
response = requests.get(url_bovespa)
soup = bsp(response.content, "html.parser")

# %%
content = soup.find("iframe", id='ctl00_contentPlaceHolderConteudo_iframeCarregadorPaginaExterna').get('src')
new_url = 'http://bvmf.bmfbovespa.com.br/' + content.lstrip('../../')
new_url
# Out:
# 'http://bvmf.bmfbovespa.com.br/pt-br/mercados/acoes/empresas/ExecutaAcaoConsultaInfoEmp.asp?CodCVM=25291&ViewDoc=1&AnoDoc=2020&VersaoDoc=3&NumSeqDoc=98701#a'

# %%
content_url = f'http://bvmf.bmfbovespa.com.br/pt-br/mercados/acoes/empresas/ExecutaAcaoConsultaInfoEmp.asp?CodCVM={code}&ViewDoc=1&AnoDoc=2020&VersaoDoc=3&NumSeqDoc=98701#a'

# %% [markdown]
# ### using pandas read_html to get the information in a list with dataframe objects using the previous url

# %%
wtf = pd.read_html(new_url)

# %%
wtf[0]
# Out:
#                          0                                                  1
# 0          Nome de Pregão:                                       3R PETROLEUM
# 1   Códigos de Negociação:  Mais Códigos  RRRP3  RRRP3  Códigos ISIN:  BRR...
# 2                    CNPJ:                                 12.091.809/0001-55
# 3     Atividade Principal:   Exploração E Produção de Petróleo E Gás Natural.
# 4  Classificação Setorial:  Petróleo. Gás e Biocombustíveis / Petróleo. Gá...

# %%
wtf[2].T
# Out:
#                                                                                0  \
# Balanço Patrimonial - Consolidado  Ativo Imobilizado, Investimentos e Intangível
# 30/09/2020                                                               362.541
# 31/12/2019                                                               265.749
#
#                                              1                   2  \
# Balanço Patrimonial - Consolidado  Ativo Total  Património Líquido
# 30/09/2020                             400.857             218.364
# 31/12/2019                             396.444             236.793
#
#                                                                              3
# Balanço Patrimonial - Consolidado  Patrimônio Líquido Atribuído à Controladora
# 30/09/2020                                                             218.364
# 31/12/2019                                                             236.793

# %%
pd.concat([wtf[2],wtf[3], wtf[4]], axis=1)
# Out:
#                Balanço Patrimonial - Consolidado  30/09/2020  31/12/2019  \
# 0  Ativo Imobilizado, Investimentos e Intangível     362.541     265.749
# 1                                    Ativo Total     400.857     396.444
# 2                             Património Líquido     218.364     236.793
# 3    Patrimônio Líquido Atribuído à Controladora     218.364     236.793
# 4                                            NaN         NaN         NaN
# 5                                            NaN         NaN         NaN
# 6                                            NaN         NaN         NaN
#
#              Demonstração do Resultado - Consolidado 01/01/2020 a 30/09/2020  \
# 0                                   Receita de Venda                  27.556
# 1                                    Resultado Bruto                  13.400
# 2              Resultado de Equivalência Patrimonial                       0
# ...

# %%
pd.read_html('https://www.rad.cvm.gov.br/ENETCONSULTA/frmGerenciaPaginaFRE.aspx?NumeroSequencialDocumento=96710&CodigoTipoInstituicao=2')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-186-fd7316efd9f6> in <module>
#       1 import html5lib
# ----> 2 pd.read_html('https://www.rad.cvm.gov.br/ENETCONSULTA/frmGerenciaPaginaFRE.aspx?NumeroSequencialDocumento=96710&CodigoTipoInstituicao=2')
#
# c:\users\amand\.venvs\lewagon\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# c:\users\amand\.venvs\lewagon\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
# ...
