# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Lucros_atual.xlsx').drop(columns=['Unnamed: 0','index'])

# %%
df.head()
# Out:
#                                Empresas 01/01/2020 a 31/03/2020  \
# 0                  AES TIETE ENERGIA SA                  75.319
# 1                             ALEF S.A.      -85.96799999999999
# 2                     ALGAR TELECOM S/A                  44.977
# 3  ALIANSCE SONAE SHOPPING CENTERS S.A.                 116.286
# 4         AMPLA ENERGIA E SERVICOS S.A.                  21.791
#
#   01/04/2020 a 30/06/2020 01/07/2020 a 30/09/2020  01/10/2020 a 31/12/2020  \
# 0                 118.959                  51.143                      NaN
# 1     -11.270999999999999                 -15.218                      NaN
# 2       85.21600000000001                     0.0                      NaN
# 3                  45.185                  28.412                      NaN
# 4                  27.783                 -53.523                      NaN
#
#   01/01/2019 a 31/03/2019 01/04/2019 a 30/06/2019 01/07/2019 a 30/09/2019  \
# ...

# %%
df.to_excel('Lucros_atual.xlsx')
